# %%
# %matplotlib inline
from ppclass import pp
import matplotlib.pyplot as mpl
mpl.rcParams['lines.linewidth'] = 3.0

# %%
instant = pp(nopickle=True)
instant.file = "/home/aspiga/data/dynamico-giant/Xhistins_270.nc"
instant.var = "u"
instant.useindex = "1100"
instant.z = 5
instant.t = 0
instant.colorbar = "seismic"
instant.vmin, instant.vmax = -90., 90.
instant.div = 36
instant.fmt = "%.0f"
instant.proj = "ortho"
instant.blat = 15.
instant.quiet = True
instant.xp, instant.yp = 12, 12
instant.title = ""
instant.getplot()
instant.filename = "sphereu"
instant.out = "pdf" ; m = instant.plot() ; instant.out = None
instant.out = "png" ; instant.res = 300 ; m = instant.plot() ; instant.out = None ; instant.res = 150
# Out:
# /home/aspiga/soft/conda/miniconda2/envs/py2/lib/python2.7/site-packages/mpl_toolkits/basemap/__init__.py:1711: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:
# **** Saving file in pdf format... Please wait.
# **** Saving file in png format... Please wait.

# %%
instant.var = ["temperature","u","v"]
instant.vargoal = ["main","vector","vector"]
instant.z = 15
instant.compute = "pert_x"
instant.svx, instant.svy = 10, 10
instant.wscale = 20
instant.vmin, instant.vmax = -1., 1.
instant.div = 20
instant.fmt = "%.1f"
instant.ymin, instant.ymax = -40,40
instant.proj = "cyl"
instant.getplot()
instant.filename = "tropicalv"
instant.out = "pdf" ; m = instant.plot()
instant.out = "png" ; instant.res = 300 ; m = instant.plot() ; instant.out = None ; instant.res = 150
# Out:
# **** Saving file in pdf format... Please wait.
# **** Saving file in png format... Please wait.

# %% [markdown]
# ## PV maps
# This corresponds to tpot 205K (level 2 in the file)

# %%
instant = pp(nopickle=True)
instant.file = "/home/aspiga/data/dynamico-giant/PVnew_Xhistins_172_red.nc"
instant.var = "relative_PV"
instant.useindex = "1100"
instant.z = 2
instant.t = 2
instant.colorbar = "seismic"
instant.vmin, instant.vmax = -5., +5.
instant.div = 50
instant.fmt = "%.1f"
instant.proj = "ortho"
instant.blat, instant.blon = 35., -90.
instant.quiet = True
#instant.verbose = True
instant.xp, instant.yp = 12, 12
instant.title = ""
instant.units = r'$10^{-7}$ m$^2$ s$^{-1}$ K kg$^{-1}$'
instant.get()
instant = instant*1.e7
instant.plot()
instant.filename = "vorti"
instant.out = "pdf" ; m = instant.plot() ; instant.out = None 
instant.out = "png" ; instant.res = 300 ; m = instant.plot() ; instant.out = None ; instant.res = 150
# Out:
# **** Saving file in pdf format... Please wait.
# **** Saving file in png format... Please wait.

# %%
instant.file = "/home/aspiga/data/dynamico-giant/Xhistins_172.nc"
instant.var = "v"
instant.units = r'm s$^{-1}$'
instant.z = 5
instant.vmin, instant.vmax = -30., +30.
instant.getplot()
instant.filename = "spherev_vorti"
instant.out = "pdf" ; m = instant.plot()
instant.out = "png" ; instant.res = 300 ; m = instant.plot() ; instant.out = None ; instant.res = 150
# Out:
# **** Saving file in pdf format... Please wait.
# **** Saving file in png format... Please wait.

# %%
instant = pp(nopickle=True)
instant.file = "/home/aspiga/data/dynamico-giant/PVnew_Xhistins_270_red.nc"
instant.var = "PV"
instant.superpose = True
instant.useindex = "1100"
instant.z = 2
instant.t = 2
instant.x = "-360,360"
instant.fmt = "%.1f"
#instant.verbose = True
instant.xp, instant.yp = 16, 6
instant.title = ""
instant.units = r'$10^{-6}$ m$^2$ s$^{-1}$ K kg$^{-1}$'
instant.ymin, instant.ymax = -8., 8.
instant.nyticks = 16
instant.get()
instant = instant*1.e6
instant.filename = "pvprof"
instant.out = "pdf"
instant.defineplot()
instant.p[0].marker = None
instant.p[0].ylabel = "Ertel PV ("+instant.units+")"
m = instant.makeplot()
instant.out = None
# Out:
# **** PPCLASS. Done step: init
# **** PPCLASS. Done step: defined
# **** PPCLASS. Done step: retrieved
# **** PPCLASS. Done step: definedplot
# **** PPCLASS. Done step: makeplot
# **** Saving file in pdf format... Please wait.

# %%
instant.var = "u"
instant.ymin, instant.ymax = -80., 80.
instant.get()
instant.defineplot()
instant.p[0].marker = None
instant.filename = "uprof"
instant.out = "pdf"
m = instant.makeplot()
instant.out = None
# Out:
# **** PPCLASS. Done step: definedplot
# **** PPCLASS. Done step: defined
# **** PPCLASS. Done step: retrieved
# **** PPCLASS. Done step: definedplot
# **** PPCLASS. Done step: makeplot
# **** Saving file in pdf format... Please wait.
