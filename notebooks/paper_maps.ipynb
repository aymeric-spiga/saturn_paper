# %%
# %matplotlib inline
from ppclass import pp
import matplotlib.pyplot as mpl
mpl.rcParams['lines.linewidth'] = 3.0

# %%
instant = pp(nopickle=True)
instant.file = "/home/aspiga/data/dynamico-giant/Xhistins_270.nc"
instant.var = "u"
instant.useindex = "1100"
instant.z = 5
instant.t = 0
instant.colorbar = "seismic"
instant.vmin, instant.vmax = -90., 90.
instant.div = 36
instant.fmt = "%.0f"
instant.proj = "ortho"
instant.blat = 15.
instant.quiet = True
instant.xp, instant.yp = 12, 12
instant.title = ""
instant.getplot()
instant.filename = "sphereu"
instant.out = "pdf" ; m = instant.plot() ; instant.out = None
instant.out = "jpg" ; instant.res = 300 ; m = instant.plot() ; instant.out = None ; instant.res = 150
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-87fffb883644> in <module>()
#      17 instant.filename = "sphereu"
#      18 instant.out = "pdf" ; m = instant.plot() ; instant.out = None
# ---> 19 instant.out = "jpg" ; instant.res = 300 ; m = instant.plot() ; instant.out = None ; instant.res = 150
#
# /home/aspiga/soft/planetoplot/modules/ppclass.pyc in plot(self, extraplot)
#    1129     def plot(self,extraplot=0):
#    1130         self.defineplot(extraplot=extraplot)
# -> 1131         self.makeplot()
#    1132         return self
#    1133
#
# /home/aspiga/soft/planetoplot/modules/ppclass.pyc in makeplot(self)
#    1110         if not self.quiet: print "**** PPCLASS. Done step: makeplot"
#    1111         if (self.n == self.howmanyplots):
# ...

# %%
instant.var = ["temperature","u","v"]
instant.vargoal = ["main","vector","vector"]
instant.z = 15
instant.compute = "pert_x"
instant.svx, instant.svy = 10, 10
instant.wscale = 20
instant.vmin, instant.vmax = -1., 1.
instant.div = 20
instant.fmt = "%.1f"
instant.ymin, instant.ymax = -40,40
instant.proj = "cyl"
instant.getplot()
instant.filename = "tropicalv"
instant.out = "pdf" ; m = instant.plot()
instant.out = "png" ; instant.res = 300 ; m = instant.plot() ; instant.out = None ; instant.res = 150

# %% [markdown]
# ## PV maps
# This corresponds to tpot 205K (level 2 in the file)

# %%
instant = pp(nopickle=True)
instant.file = "/home/aspiga/data/dynamico-giant/PVnew_Xhistins_172_red.nc"
instant.var = "relative_PV"
instant.useindex = "1100"
instant.z = 2
instant.t = 2
instant.colorbar = "seismic"
instant.vmin, instant.vmax = -5., +5.
instant.div = 50
instant.fmt = "%.1f"
instant.proj = "ortho"
instant.blat, instant.blon = 35., -90.
instant.quiet = True
#instant.verbose = True
instant.xp, instant.yp = 12, 12
instant.title = ""
instant.units = r'$10^{-7}$ m$^2$ s$^{-1}$ K kg$^{-1}$'
instant.get()
instant = instant*1.e7
instant.plot()
instant.filename = "vorti"
instant.out = "pdf" ; m = instant.plot() ; instant.out = None 
instant.out = "png" ; instant.res = 300 ; m = instant.plot() ; instant.out = None ; instant.res = 150

# %%
instant.file = "/home/aspiga/data/dynamico-giant/Xhistins_172.nc"
instant.var = "v"
instant.units = r'm s$^{-1}$'
instant.z = 5
instant.vmin, instant.vmax = -30., +30.
instant.getplot()
instant.filename = "spherev_vorti"
instant.out = "pdf" ; m = instant.plot()
instant.out = "png" ; instant.res = 300 ; m = instant.plot() ; instant.out = None ; instant.res = 150
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6f70979ad472> in <module>()
#       7 instant.filename = "spherev_vorti"
#       8 instant.out = "pdf" ; m = instant.plot()
# ----> 9 instant.out = "jpg" ; instant.res = 300 ; m = instant.plot() ; instant.out = None ; instant.res = 150
#
# /home/aspiga/soft/planetoplot/modules/ppclass.pyc in plot(self, extraplot)
#    1129     def plot(self,extraplot=0):
#    1130         self.defineplot(extraplot=extraplot)
# -> 1131         self.makeplot()
#    1132         return self
#    1133
#
# /home/aspiga/soft/planetoplot/modules/ppclass.pyc in makeplot(self)
#    1110         if not self.quiet: print "**** PPCLASS. Done step: makeplot"
#    1111         if (self.n == self.howmanyplots):
# ...

# %%
instant.file = "/home/aspiga/data/dynamico-giant/Xhistins_172.nc"
instant.var = "u"
instant.units = r'm s$^{-1}$'
instant.z = 5
instant.vmin, instant.vmax = -90., 90.
instant.div = 36
instant.getplot()
instant.filename = "sphereu_vorti"
instant.out = "pdf" ; m = instant.plot()
instant.out = "png" ; instant.res = 300 ; m = instant.plot() ; instant.out = None ; instant.res = 150

# %%
instant2 = pp(nopickle=True)
instant2.file = "/home/aspiga/data/dynamico-giant/PVnew_Xhistins_270_red.nc"
instant2.var = "PV"
instant2.superpose = True
instant2.useindex = "1100"
instant2.z = 2
instant2.t = 2
instant2.x = "-360,360"
instant2.fmt = "%.1f"
#instantv.verbose = True
instant2.xp, instant2.yp = 16, 6
instant2.title = ""
instant2.units = r'$10^{-6}$ m$^2$ s$^{-1}$ K kg$^{-1}$'
instant2.ymin, instant2.ymax = -8., 8.
instant2.nyticks = 16
instant2.get()
instant2 = instant2*1.e6
instant2.filename = "pvprof"
instant2.out = "pdf"
instant2.defineplot()
instant2.p[0].marker = None
instant2.p[0].ylabel = "Ertel PV ("+instant.units+")"
m = instant2.makeplot()
instant2.out = None
# Out:
# **** PPCLASS. Done step: init
# **** PPCLASS. Done step: defined
# **** PPCLASS. Done step: retrieved
# **** PPCLASS. Done step: definedplot
# **** PPCLASS. Done step: makeplot

# %%
instant2.var = "u"
instant2.ymin, instant2.ymax = -80., 80.
instant2.get()
instant2.defineplot()
instant2.p[0].marker = None
instant2.filename = "uprof"
instant2.out = "pdf"
m = instant2.makeplot()
instant2.out = None
# Out:
# **** PPCLASS. Done step: definedplot
# **** PPCLASS. Done step: defined
# **** PPCLASS. Done step: retrieved
# **** PPCLASS. Done step: definedplot
# **** PPCLASS. Done step: makeplot
